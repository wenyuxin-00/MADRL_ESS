# %%
from pathlib import Path
import os
import sys

_here = Path.cwd().resolve()
_repo_root = next(path for path in (_here, *_here.parents) if (path / "configs" / "cfg.py").exists())
os.chdir(_repo_root)
sys.path.insert(0, str(_repo_root))

import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint
from IPython.display import Markdown, display

from data.share_data import load_share_data
from scripts.madrl import SCHEMES, plot_madrl_outputs, run_madrl_scheme_experiment
from utils.run_artifacts import load_experiment_context

# %%
run_dir = Path("artifacts/runs/20260504_234339_01e73bd1")
scheme_name = "madrl_base_safe"
cfg, run_dir = load_experiment_context(run_dir)
share_data = load_share_data(run_dir / "share_data", cfg)
assert int(share_data.manifest["sequence_length"]) == int(cfg.obs.sequence_length)
spec = next(item for item in SCHEMES if item["scheme"] == scheme_name)
train_episodes = 500
w_voltage, w_line, w_trafo = spec["reward"]

display(Markdown("# MADRL + Safety Penalty + LSTM Forecast"))
display(pd.DataFrame([{
    "run_dir": str(run_dir),
    "scheme": scheme_name,
    "controller": spec["controller"],
    "train_episodes": train_episodes,
    "device": cfg.runtime.device,
    "train_window_days": int(cfg.env.train_window_days),
    "train_episode_steps": int(cfg.env.episode_steps) * int(cfg.env.train_window_days),
    "action_dim": int(cfg.model.action_dim),
    "max_charge_rate": float(cfg.env.max_charge_rate),
    "init_soc": float(cfg.env.init_soc),
    "train_init_soc_low": float(cfg.env.train_init_soc_low),
    "train_init_soc_high": float(cfg.env.train_init_soc_high),
    "batch_size": int(cfg.train.batch_size),
    "gamma": float(cfg.algo.gamma),
    "tau": float(cfg.algo.tau),
    "hidden_dim": int(cfg.model.hidden_dim),
    "n_step_return": int(cfg.train.n_step_return),
    "w_voltage_pen": float(w_voltage),
    "w_line_pen": float(w_line),
    "w_trafo_pen": float(w_trafo),
}]))
# Out:
# # MADRL + Safety Penalty + LSTM Forecast
#                                    run_dir           scheme     controller  \
# 0  artifacts\runs\20260504_234339_01e73bd1  madrl_base_safe  MADRL_PENALTY
#
#    train_episodes device  train_window_days  train_episode_steps  action_dim  \
# 0             500   cuda                  7                  672           2
#
#    max_charge_rate  init_soc  train_init_soc_low  train_init_soc_high  \
# 0              0.5      0.05                0.05                 0.05
#
#    batch_size  gamma   tau  hidden_dim  n_step_return  w_voltage_pen  \
# 0         512  0.999  0.01         256             96          400.0
#
#    w_line_pen  w_trafo_pen
# 0         0.0         10.0

# %%
result = run_madrl_scheme_experiment(cfg, run_dir, share_data, spec, episodes=train_episodes)

display(Markdown("## Train Summary"))
display(result["train_summary"])

saved = result["records"][scheme_name]
display(Markdown("## Test Metrics"))
display(saved["metrics_df"])
display(Markdown("## Agent Summary"))
display(saved["rollout"].summary)
pprint({"record_dir": str(saved["record_dir"])})
# Out:
# train madrl_base_safe:   0%|          | 0/500 [00:00<?, ?episode/s]
# MADRL + Safety Penalty + LSTM Forecast/lstm:   0%|          | 0/15 [00:00<?, ?episode/s]
# ## Train Summary
#             scheme     controller                                   label  \
# 0  madrl_base_safe  MADRL_PENALTY  MADRL + Safety Penalty + LSTM Forecast
#
#     algo  projection  episodes   steps  updates    elapsed_s vec_env_kind  \
# 0  MATD3       False       500  336000    82657  3988.696832      subproc
#
#    ... action_sample_s   env_step_s  replay_add_s  sample_update_s    other_s  \
# 0  ...      222.827601  1786.523544     38.665072      1926.897372  13.783243
#
#    batch_size  num_envs  parallel_episode_sampling  \
# 0         512         4              unique_active
#
#                                           model_path  \
# 0  artifacts\runs\20260504_234339_01e73bd1\models...
#
#                                           record_dir
# 0  artifacts\runs\20260504_234339_01e73bd1\result...
#
# [1 rows x 21 columns]
# ## Test Metrics
#                                controller    soc_mode  \
# 0  MADRL + Safety Penalty + LSTM Forecast  continuous
#
#    storage_charge_cost_total_eur  storage_discharge_revenue_total_eur  \
# 0                     978.592929                           980.056539
#
#    storage_profit_total_eur  storage_objective_total_eur  \
# 0                   1.46361                     -1.46361
#
#    system_other_cost_eur  total_eur  soc_penalty_total  voltage_penalty_total  \
# 0                    0.0  -1.463614          15.924883               0.074388
#
#    ...  voltage_step_delta_p95_pu  voltage_step_delta_max_pu  \
# 0  ...                   0.014271                   0.065317
#
#    voltage_spread_mean_pu  voltage_spread_max_pu  trafo_overload_steps  \
# 0                0.008832               0.054602                    13
#
#    trafo_loading_max_pct  feeder_netload_ramp_mean_abs_kw  \
# 0             149.064316                        27.413601
#
#    feeder_netload_ramp_max_kw  battery_net_power_kw_mean_abs  \
# 0                  178.712097                       34.44177
#
#    returned_primary_objective_eur
# 0                       -1.463614
#
# [1 rows x 32 columns]
# ## Agent Summary
#                                controller  agent_id agent_profile      reward  \
# 0  MADRL + Safety Penalty + LSTM Forecast         0         SFH12 -100.256386
# 1  MADRL + Safety Penalty + LSTM Forecast         1         SFH18   58.015670
# 2  MADRL + Safety Penalty + LSTM Forecast         2         SFH20   48.517963
#
#    storage_profit_eur  mean_soc
# 0         -104.710576  0.491079
# 1           55.181276  0.412771
# 2           50.992914  0.178105
# {
# 'record_dir'
# :
# 'artifacts\\runs\\20260504_234339_01e73bd1\\results\\lstm\\MADRL_PENALTY\\record'
# }

# %%
plt.close("all")
figures = plot_madrl_outputs(result, run_dir)
_plot_specs = [
    ("1. 电力电量平衡", "madrl_base_safe_power_balance"),
    ("2. 电价", "madrl_base_safe_price"),
    ("3. 总体储能充放功率与 SoC", "madrl_base_safe_battery_soc"),
    ("4. 电压", "madrl_base_safe_voltage"),
    ("5. 净负荷", "madrl_base_safe_net_load"),
    ("6. 训练奖励", "madrl_base_safe_learning_curve"),
]
for title, name in _plot_specs:
    print(title)
    display(figures[name])
    plt.close(figures[name])
# Out:
# C:\Users\10856\Desktop\GithubProject\MADRL_ESS\utils\records.py:392: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(handles=[], labels=[], loc="upper right")
# 1. 电力电量平衡
# 2. 电价
# 3. 总体储能充放功率与 SoC
# 4. 电压
# 5. 净负荷
# 6. 训练奖励
